# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('Supplier Forecast -UAE.csv', encoding='latin1')
# pd.read_csv('Consolidate Sales Reports.csv', encoding='latin1')
# Out:
#         Last Update:                                         Unnamed: 1  \
# 0        Start From:                                                NaN
# 1         Total Day:                                                NaN
# 2       Catalogue NÂ                                              Title
# 3                NaN  Baseus Cafule Cable Durable Nylon Braided Wire...
# 4    BTC-320BK                      Brave 2-port USB Wall Charger Black
# 5            BAC-106         Brave Lightning to 3.5mm Audio Cable Black
# 6    BHL-712          BRAVE LOTTO SERIES MAGNETIC CAR MOUNTS        ...
# 7    BHL-713          BRAVE 2-IN-1 UNIVERSAL MAGNETIC HOLDER        ...
# 8          BTC-320BK                Brave 2-port USB Wall Charger Black
# 9            BAC-106         Brave Lightning to 3.5mm Audio Cable Black
# 10           BTC-320                Brave 2-port USB Wall Charger White
# 11           BTC-320                Brave 2-port USB Wall Charger White
# ...
